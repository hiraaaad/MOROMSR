# %% [markdown]
# Packages required for running this code are:
# - Python: 3.7
# - Numpy: 1.17.4
# - Numba
# - Pandas: 0.25.3
# - NetworkX 2.5
# - codetiming 1.2

# %%
from core_aco.phoenix_mmas import phoenix_mmas
from core_aco_case3.phoenix_mmas_case3 import phoenix_mmas_case3
from core.phoenix_ga import phoenix_ga
from core_case3.phoenix_ga_case3 import phoenix_ga_case3
from core_aco.manual_algorithm import manual_alg

# %%
# for example:
stockpile = 4
number_bench = 4
number_cut = 10
demand = 1
direction = 0
phoenix = 1
ls = 0
iteration = 1
case = 1
alpha = 1
beta = 2
rho = 0.5
num_ant = 10
num_gen = 100

# %%
phoenix_mmas(stockpile, number_bench, number_cut, demand, direction, phoenix, ls, iteration, case, alpha, beta, rho, num_ant, num_gen)
# Out:
# x
# df_cost setup was successful
# 141651
# [1.0, 2.0, 101.0, 101.51526487121757, 103.0]
# [1.0351093423174678, 2.0, 1.0, 101.0, 103.0]
# [1.0476661433200591, 1.0, 2.0, 1.1077559128203138, 101.0, 103.0]
# [1.0443091948989864, 2.0, 1.1129764334979249, 1.0, 101.0, 103.0]
# [1.0, 2.0, 1.1071680848665388, 1.07936627576956, 101.0, 103.0]
# [2.0, 1.0500148009046195, 1.0, 101.0, 103.0]
# [1.05136032576247, 1.0, 1.5814743313261976, 2.0, 1.128503274387453, 101]
# [1.0479025087435707, 1.5609038524529102, 2.0, 1.1351092054535128, 1.0, 101]
# [1.0, 1.4323425829997314, 1.7166895626428005, 2.0, 1.090910070782057, 1.0610715624790683]
# [1.0, 1.0678757896793523, 1.503317693521192, 1.751194695308599, 2.0, 1.1112310404590815, 1.0390900324917323]
# [1.4253940543447763, 1.71348173872995, 2.0, 1.068633217104741, 1.0, 1.0776758119534442]
# [1.057179040849735, 1.0195843033299135, 1.3868654719635947, 1.6948348250807683, 2.0, 1.0, 1.0825211464539277]
# ...

# %%
phoenix_mmas_case3(stockpile, number_bench, number_cut, demand, direction, phoenix, ls, iteration, 3, alpha, beta, rho, num_ant, num_gen)

# %%
greedy_alpha = 1
case =3 
phoenix_ga_case3(stockpile, number_bench, number_cut, demand, greedy_alpha, direction, phoenix, ls, iteration, case)

# %%
case = 2
greedy_alpha = 0
phoenix_ga(stockpile, number_bench, number_cut, demand, greedy_alpha, direction, phoenix, ls, iteration, case)
# Out:
# df_cost setup was successful
# iteration 1:
#
# Time spent: 0.02
